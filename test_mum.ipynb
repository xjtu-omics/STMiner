# %%
from SPFinder import SPFinder

# %%
sp = SPFinder()
sp.read_h5ad(file='E://paper_data/mouse/MouseBrain_P7_section1_bin50.h5ad')

# %%
# sp.merge_bin(40)
sp.fit_pattern(n_top_genes=200, n_comp=30, min_cells=200)
sp.build_distance_array()
# Out:
# ...
# Building distance array...: 100%|██████████| 200/200 [03:53<00:00,  1.17s/it]

# %%
sp.cluster_gene(n_clusters=8, mds_components=30)

# %%
sp.plot_pattern(vmax=99)

# %%
sp.plot_genes(label=4, vmax=99, reverse_y=True)
